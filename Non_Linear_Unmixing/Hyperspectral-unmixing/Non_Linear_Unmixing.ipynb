# %%
import nonlinear_unmixing
# Out:
# 	Data Source:   '/home/shahin/Desktop/Mid_Term/Non_Linear_Unmixing/Hyperspectral-unmixing/samson/samson_1.img'
# 	# Rows:             95
# 	# Samples:          95
# 	# Bands:           156
# 	Interleave:        BSQ
# 	Quantization:  16 bits
# 	Data format:     int16
# <class 'spectral.image.ImageArray'>
#   End members indexes: [(84, 4), (1, 1), (29, 69)]
# (95, 95, 3)
# /home/shahin/miniconda3/lib/python3.10/site-packages/pysptools/abundance_maps/amaps_int.py:127: UserWarning: In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns
#   warnings.warn('In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns')
# dict_keys(['__header__', '__version__', '__globals__', 'cood', 'A', 'M'])
# gt shpae- (9025, 3)
# (2257, 3)
# (6768, 3)
# (2257, 3)
# (6768, 3)
# ...

# %% [markdown]
# $\newline$
# $\newline$
# <a name=''>$\large{\bf{\text{References}}}$</a>
# $\newline$
# $\newline$
# - <a name=''>[$\bf{\underline{Non-Linear Unmixing}}$](https://github.com/deepanshi-s/Hyperspectral-unmixing)</a>
# $\newline$
# $\newline$
# $\newline$
# $\newline$
